# %%
import glob
import pandas as pd
from dotenv import load_dotenv
import os
from urllib.parse import urlparse

# Load variables from the .env file into the environment
load_dotenv()

# Accessing variables
folder_path = os.getenv('FOLDER_PATH')

# %%
# Step 3: Use glob to Find CSV Files
csv_files = glob.glob(folder_path + '/*.csv')

# Print out the files found by glob.glob() for debugging
print("CSV Files found:")
print(csv_files)

# Step 4: Load CSV Files Using pandas
dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

# Step 5: Process or Analyze the DataFrames (Optional)
# Example: Concatenate all DataFrames into a single DataFrame
if dfs:
    combined_df = pd.concat(dfs, ignore_index=True)
    print("Combined DataFrame:")
    print(combined_df.head())
else:
    print("No CSV files found in the specified folder.")
# Out:
# CSV Files found:
# ...

# %% [markdown]
# Sorting out Links

# %%
#Part 1
#select only relevant columns
combined_df_dropduplicate = combined_df.drop_duplicates()
Links = combined_df_dropduplicate[['Link1','Link2','Link3','Link4','Link5','Link6','Link7','Link8']]

# Melt the DataFrame to combine all link columns into one column
melted_links = Links.melt(value_name='Link').drop('variable', axis=1)

# Drop rows with NaN values
combined_links = melted_links.dropna()

# Reset the index
combined_links.reset_index(drop=True, inplace=True)

# The resulting DataFrame with a single column of links
combined_links

#Part 2
# Function to extract the domain from a URL
def extract_domain(url):
    parsed_url = urlparse(url)
    return parsed_url.netloc

# Apply the function to extract domains
combined_links['Domain'] = combined_links['Link'].apply(extract_domain)

# The resulting DataFrame with domains
combined_links

# Display Unique Domains
# combined_links['Domain'].unique()
# Out:
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_9436\3322594930.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_links['Domain'] = combined_links['Link'].apply(extract_domain)
#                                                    Link            Domain
# 0     https://www.linkedin.com/in/bazil-suhaimi-buan...  www.linkedin.com
# 1      https://www.linkedin.com/in/adriad-choo-87b297a2  www.linkedin.com
# 2     https://www.linkedin.com/in/osman-pauzi-abdul-...  www.linkedin.com
# 3     https://www.linkedin.com/in/mithin-sukumaran-4...  www.linkedin.com
# 4     https://www.linkedin.com/in/sree-raguraman-6a7...  www.linkedin.com
# ...                                                 ...               ...
# ...

# %%
# Extract column names
column_names = combined_df.columns.tolist()

# Create a new DataFrame with the column names
df_columns = pd.DataFrame(column_names, columns=['column'])

# Sort the DataFrame by the column names in ascending order
df_columns_sorted = df_columns.sort_values(by='column').reset_index(drop=True)

# Display the sorted DataFrame
df_columns_sorted
# Out:
#                     column
# 0           Business Email
# 1          Business Email1
# 2          Business Email2
# 3          Business Email3
# 4                  Company
# 5        Education Degree1
# 6        Education Degree2
# 7        Education Degree3
# 8        Education Degree4
# 9        Education Degree5
# 10       Education Degree6
# 11       Education Degree7
# 12        Education Ended1
# 13        Education Ended2
# 14        Education Ended3
# 15        Education Ended4
# 16        Education Ended5
# 17        Education Ended6
# 18        Education Ended7
# 19      Education Faculty1
# 20      Education Faculty2
# 21      Education Faculty3
# 22      Education Faculty4
# 23      Education Faculty5
# 24      Education Faculty6
# 25      Education Faculty7
# 26      Education Started1
# 27      Education Started2
# 28      Education Started3
# 29      Education Started4
# 30      Education Started5
# 31      Education Started6
# 32      Education Started7
# ...
