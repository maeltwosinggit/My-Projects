# %%
import glob
import pandas as pd
from dotenv import load_dotenv
import os
from urllib.parse import urlparse
import numpy as np

# Load variables from the .env file into the environment
load_dotenv()

# Accessing variables
folder_path = os.getenv('FOLDER_PATH')

# %%
# Step 3: Use glob to Find CSV Files
csv_files = glob.glob(folder_path + '/*.csv')

# Print out the files found by glob.glob() for debugging
print("CSV Files found:")
print(csv_files)

# Step 4: Load CSV Files Using pandas
dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

# Step 5: Process or Analyze the DataFrames (Optional)
# Example: Concatenate all DataFrames into a single DataFrame
if dfs:
    combined_df = pd.concat(dfs, ignore_index=True)
    print("Combined DataFrame:")
    print(combined_df.head())
else:
    print("No CSV files found in the specified folder.")
# Out:
# CSV Files found:
# ['C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (1).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (10).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (11).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (12).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (2).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (3).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (4).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (5).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (6).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (7).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (8).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports (9).csv', 'C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\\SignalHire_exports.csv']
# Combined DataFrame:
#                                  Id  Uploaded Link First Name  \
# 0  66fae66b5f0840869ab4a494f26b5702            NaN      Bazil
# 1  f0683fc89f0c4a36a2a97020f134e9d6            NaN     Adriad
# 2  67c20f12bad1447fbc0b85bb29afe760            NaN      Osman
# 3  55a6d7112e7f4cdc9e15117100017e35            NaN     Mithin
# 4  a0c2dea99a2c425ea18816c9e7101d1e            NaN       Sree
#
#            Last Name                          Position  \
# 0      Suhaimi Buang  Assistant Manufacturing Engineer
# 1               Choo               HR & Admin Director
# 2  Pauzi Abdul Hapip                   Senior Engineer
# 3          Sukumaran                   Project Manager
# 4          RaguRaman              Purchasing Executive
#
#                                     Company                  Location  \
# 0  ECO PAPER PRODUCTS MANUFACTURING SDN BHD  Kampung Koalam, Malaysia
# 1                  Puratos Malaysia Sdn Bhd  Kuala Selangor, Malaysia
# 2                   Premium Sound Solutions    Pos Penangau, Malaysia
# 3            PRECISION SPRINGS (M) SDN.BHD.     Butterworth, Malaysia
# 4                   PSI Incontrol Sdn. Bhd.    Kuala Lumpur, Malaysia
#
#                       Spoken Language  Recruitment Stage  Recruitment Status  \
# 0                                 NaN                NaN                 NaN
# 1  Bahasa Malaysia, English, Mandarin                NaN                 NaN
# 2                                 NaN                NaN                 NaN
# 3                                 NaN                NaN                 NaN
# 4                                 NaN                NaN                 NaN
#
#    ... Experience Ended15 Experience Summary15 Business Email3  \
# 0  ...                NaN                  NaN             NaN
# 1  ...                NaN                  NaN             NaN
# 2  ...                NaN                  NaN             NaN
# 3  ...                NaN                  NaN             NaN
# 4  ...                NaN                  NaN             NaN
#
#   Education Degree7 Education Faculty7 Education University7  \
# 0               NaN                NaN                   NaN
# 1               NaN                NaN                   NaN
# 2               NaN                NaN                   NaN
# 3               NaN                NaN                   NaN
# 4               NaN                NaN                   NaN
#
#   Education Started7 Education Ended7 Link7 Link8
# 0                NaN              NaN   NaN   NaN
# 1                NaN              NaN   NaN   NaN
# 2                NaN              NaN   NaN   NaN
# 3                NaN              NaN   NaN   NaN
# 4                NaN              NaN   NaN   NaN
#
# [5 rows x 140 columns]

# %% [markdown]
# Keeping Relevant Columns Only

# %%
# Create the 'Full Name' column by merging 'First Name' and 'Last Name' with a space as the delimiter
combined_df['Full Name'] = combined_df['First Name'] + ' ' + combined_df['Last Name']

# Drop the 'First Name' and 'Last Name' columns
keepcolumn_df = combined_df[['Full Name','Company','Position','Headline',
'Personal Email1',
'Personal Email2',
'Personal Email3',
'Business Email',
'Business Email1',
'Business Email2',
'Business Email3',
'Link1',
'Link2',
'Link3',
'Link4',
'Link5',
'Link6',
'Link7',
'Link8'
]]

SHdata_df = keepcolumn_df.drop_duplicates()
SHdata_df
# Out:
#                     Full Name                                   Company  \
# 0         Bazil Suhaimi Buang  ECO PAPER PRODUCTS MANUFACTURING SDN BHD
# 1                 Adriad Choo                  Puratos Malaysia Sdn Bhd
# 2     Osman Pauzi Abdul Hapip                   Premium Sound Solutions
# 3            Mithin Sukumaran            PRECISION SPRINGS (M) SDN.BHD.
# 4              Sree RaguRaman                   PSI Incontrol Sdn. Bhd.
# ...                       ...                                       ...
# 1248                   CK Wan             Respack Manufacturing Sdn Bhd
# 1249             Jivan Kasvan               Rockwool Malaysia Sdn. Bhd.
# 1250              Aizwan Aziz                           Rohde & Schwarz
# 1251        Mohd Amzar Sharif     Rinnai Manufacturing Malaysia Sdn Bhd
# 1252              BakChye Ooi                  Robert Bosch (M) Sdn Bhd
#
#                                                Position  \
# 0                      Assistant Manufacturing Engineer
# 1                                   HR & Admin Director
# 2                                       Senior Engineer
# 3                                       Project Manager
# 4                                  Purchasing Executive
# ...                                                 ...
# 1248                                  Managing Director
# 1249                             Mechanical Maintenance
# 1250                                 Assistance Manager
# 1251                    R&D Design Engineer- Structural
# 1252  Lean Consultant | Mech sub-Project Manager | M...
#
#                                                Headline  \
# 0     Graduated in Bachelor Degree Manufacturing Eng...
# 1                 MSc in Training, Leicester University
# 2                Senior Engineer at Jinko Solar Penang.
# 3                                       Project Manager
# 4     Purchasing Executive at PSI Incontrol Sdn.Bhd ...
# ...                                                 ...
# 1248                       Managing Director at Respack
# 1249  Mechanical Maintenance  at Rockwool Malaysia S...
# 1250  Well versed, experienced and versatile project...
# 1251  R&D Design Engineer- Structural at Rinnai Manu...
# 1252  Lean Consultant | Mech sub-Project Manager | M...
#
#              Personal Email1 Personal Email2 Personal Email3 Business Email  \
# 0                        NaN             NaN             NaN            NaN
# 1     adriadchoo@hotmail.com             NaN             NaN            NaN
# 2           R63690@gmail.com             NaN             NaN            NaN
# 3       mithinsuku@gmail.com             NaN             NaN            NaN
# 4                        NaN             NaN             NaN            NaN
# ...                      ...             ...             ...            ...
# 1248                     NaN             NaN             NaN            NaN
# 1249                     NaN             NaN             NaN            NaN
# 1250      aizwan22@gmail.com             NaN             NaN            NaN
# 1251      amcarisz@gmail.com             NaN             NaN            NaN
# 1252       bakchye@gmail.com             NaN             NaN            NaN
#
#                   Business Email1 Business Email2 Business Email3  \
# 0             bazil@eppmfg.com.my             NaN             NaN
# 1               achoo@puratos.com             NaN             NaN
# 2                             NaN             NaN             NaN
# 3                             NaN             NaN             NaN
# 4     raguraman@psi-incontrol.com             NaN             NaN
# ...                           ...             ...             ...
# 1248         ckwan@respack.com.my             NaN             NaN
# 1249         jivan_kasvan@bat.com             NaN             NaN
# 1250                          NaN             NaN             NaN
# 1251                          NaN             NaN             NaN
# 1252                          NaN             NaN             NaN
#
#                                                   Link1  \
# 0     https://www.linkedin.com/in/bazil-suhaimi-buan...
# 1      https://www.linkedin.com/in/adriad-choo-87b297a2
# 2     https://www.linkedin.com/in/osman-pauzi-abdul-...
# 3     https://www.linkedin.com/in/mithin-sukumaran-4...
# 4     https://www.linkedin.com/in/sree-raguraman-6a7...
# ...                                                 ...
# 1248        https://www.linkedin.com/in/ck-wan-95863675
# 1249  https://www.linkedin.com/in/jivan-kasvan-70740b6a
# 1250  https://www.linkedin.com/in/aizwan-aziz-a12835172
# 1251  https://www.linkedin.com/in/mohd-amzar-sharif-...
# 1252  https://www.linkedin.com/in/bakchye-ooi-a11a06110
#
#                                     Link2 Link3 Link4 Link5 Link6 Link7 Link8
# 0                                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1                                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     https://www.facebook.com/mithinsuku   NaN   NaN   NaN   NaN   NaN   NaN
# 4                                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                                   ...   ...   ...   ...   ...   ...   ...
# 1248                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1249                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1250                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1251                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1252                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1217 rows x 19 columns]

# %% [markdown]
# Rearrange SignalHire's Data

# %%
# emails_df = SHdata_df[['Full Name', 'Company', 'Position', 'Headline', 'Personal Email1',
#        'Personal Email2', 'Personal Email3', 'Business Email',
#        'Business Email1', 'Business Email2', 'Business Email3', 'Link1',
#        'Link2', 'Link3', 'Link4', 'Link5', 'Link6', 'Link7', 'Link8']] 

emails_df0 = SHdata_df[['Full Name', 'Company', 'Position', 'Headline','Business Email']] 
emails_df1 = SHdata_df[['Full Name', 'Company', 'Position', 'Headline', 'Personal Email1','Business Email1']] 
emails_df2 = SHdata_df[['Full Name', 'Company', 'Position', 'Headline', 'Personal Email2','Business Email2']] 
emails_df3 = SHdata_df[['Full Name', 'Company', 'Position', 'Headline', 'Personal Email3','Business Email3']] 


# renaming columns
emails_df1.rename(columns={'Personal Email1':'Personal Email','Business Email1':'Business Email'},inplace=True)
emails_df2.rename(columns={'Personal Email2':'Personal Email','Business Email2':'Business Email'},inplace=True)
emails_df3.rename(columns={'Personal Email3':'Personal Email','Business Email3':'Business Email'},inplace=True)

# Combining DataFrames
emails_df = pd.concat([emails_df0,emails_df1, emails_df2, emails_df3], ignore_index=True)

# Dropping rows where both 'Personal Email' and 'Business Email' are null
# emails_df.dropna(subset=['Personal Email', 'Business Email'], how='all', inplace=True)
emailnotnull_df = emails_df[((emails_df['Personal Email'].notna()) | (emails_df['Business Email'].notna()))] #contains email
emailnull_df = emails_df[((emails_df['Personal Email'].isna()) & (emails_df['Business Email'].isna()))] #does not contain email
# Out:
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_22832\1735603224.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails_df1.rename(columns={'Personal Email1':'Personal Email','Business Email1':'Business Email'},inplace=True)
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_22832\1735603224.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails_df2.rename(columns={'Personal Email2':'Personal Email','Business Email2':'Business Email'},inplace=True)
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_22832\1735603224.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails_df3.rename(columns={'Personal Email3':'Personal Email','Business Email3':'Business Email'},inplace=True)

# %% [markdown]
# Attaching SignalHire Full Name and Email data to Template

# %%
pretemplate = pd.DataFrame(columns=[
    'NO', 'COMPANY NAME', 'COMPANY ADDRESS', 'COMPANY ACTIVITIES', 'COMPANY TEL', 
    'COMPANY EMAIL', 'COMPANY WEBSITE', 'CONTACT SALUTATION', 'CONTACT NAME', 
    'CONTACT TEL', 'WORK EMAIL', 'CONTACT EMAIL', 'POSITION', 'SUBJECT OF INTEREST', 
    'OTHER NOTES', 'Search Status', 'Link Reference', 'LinkedIn Profile'
])

# Populate the CONTACT EMAIL and WORK EMAIL columns
pretemplate['CONTACT EMAIL'] = emailnotnull_df.apply(lambda x: x['Personal Email'], axis=1)
pretemplate['WORK EMAIL'] = emailnotnull_df.apply(lambda x: x['Business Email'], axis=1)

# Filter for non-null Personal Email and create the mapping
personal_email_filtered_df = emailnotnull_df[emailnotnull_df['Personal Email'].notnull()]
namepersonal_mapping = dict(zip(personal_email_filtered_df['Personal Email'], personal_email_filtered_df['Full Name']))

# Filter for non-null Business Email and create the mapping
business_email_filtered_df = emailnotnull_df[emailnotnull_df['Business Email'].notnull()]
namebusiness_mapping = dict(zip(business_email_filtered_df['Business Email'], business_email_filtered_df['Full Name']))

# Fill NaN values in 'COMPANY NAME' column of dftemplate_t4 using company_mapping
pretemplate['CONTACT NAME'] = pretemplate['CONTACT NAME'].fillna(pretemplate['CONTACT EMAIL'].map(namepersonal_mapping))
pretemplate['CONTACT NAME'] = pretemplate['CONTACT NAME'].fillna(pretemplate['WORK EMAIL'].map(namebusiness_mapping))

pretemplate[['CONTACT NAME','CONTACT EMAIL','WORK EMAIL']]
# pretemplate[pretemplate['CONTACT NAME']=='Angelyn Ser']
# Out:
#               CONTACT NAME            CONTACT EMAIL  \
# 213           Maggie  Chan                      NaN
# 807             Mohd Fadli                      NaN
# 920         Mohd Shafizzie                      NaN
# 973       Ahmad Khairuddin                      NaN
# 1217   Bazil Suhaimi Buang                      NaN
# ...                    ...                      ...
# 4067        Fabian Knauthe  fabianknauthe@gmail.com
# 4775            Jersie Low      jersielow@gmail.com
# 4776   Kumaran Subramaniam                      NaN
# 4777  Nor Khalilah A.Karim                      NaN
# 4781           Angelyn Ser                      NaN
#
#                             WORK EMAIL
# 213            maggie.chan@qdos.com.my
# 807                 fadli@ramly.com.my
# 920         mohd.shafizzie@renesas.com
# 973      ahmad.khairuddin@swagelok.com
# 1217               bazil@eppmfg.com.my
# ...                                ...
# 4067                               NaN
# 4775                               NaN
# 4776  ksubramaniam@rapiscansystems.com
# 4777           nor.khalilah@plexus.com
# 4781      angelynser@royalselangor.com
#
# [419 rows x 3 columns]

# %%
# Remove duplicate values in the 'Full Name' column
unique_null_df = emailnull_df[['Full Name']].drop_duplicates()
# Remove names in unique_null_df if they exist in pretemplate
filtered_unique_null_df = unique_null_df[~unique_null_df['Full Name'].isin(pretemplate['CONTACT NAME'])]

# Append new row for each name in filtered_unique_null_df to pretemplate['CONTACT NAME']
TemplateFilled_df = pretemplate.copy()
# Rename 'Full Name' to 'CONTACT NAME' to match the column in TemplateFilled_df
filtered_unique_null_df.rename(columns={'Full Name': 'CONTACT NAME'}, inplace=True)

# Concatenate the original TemplateFilled_df with the filtered names
TemplateFilled_df = pd.concat([TemplateFilled_df, filtered_unique_null_df], ignore_index=True)

TemplateFilled_df
# Out:
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_22832\2171142097.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_unique_null_df.rename(columns={'Full Name': 'CONTACT NAME'}, inplace=True)
#        NO COMPANY NAME COMPANY ADDRESS COMPANY ACTIVITIES COMPANY TEL  \
# 0     NaN          NaN             NaN                NaN         NaN
# 1     NaN          NaN             NaN                NaN         NaN
# 2     NaN          NaN             NaN                NaN         NaN
# 3     NaN          NaN             NaN                NaN         NaN
# 4     NaN          NaN             NaN                NaN         NaN
# ...   ...          ...             ...                ...         ...
# 1254  NaN          NaN             NaN                NaN         NaN
# 1255  NaN          NaN             NaN                NaN         NaN
# 1256  NaN          NaN             NaN                NaN         NaN
# 1257  NaN          NaN             NaN                NaN         NaN
# 1258  NaN          NaN             NaN                NaN         NaN
#
#      COMPANY EMAIL COMPANY WEBSITE CONTACT SALUTATION            CONTACT NAME  \
# 0              NaN             NaN                NaN            Maggie  Chan
# 1              NaN             NaN                NaN              Mohd Fadli
# 2              NaN             NaN                NaN          Mohd Shafizzie
# 3              NaN             NaN                NaN        Ahmad Khairuddin
# 4              NaN             NaN                NaN     Bazil Suhaimi Buang
# ...            ...             ...                ...                     ...
# 1254           NaN             NaN                NaN  Mohd Fidha Uddin Alias
# 1255           NaN             NaN                NaN                 Siti M.
# 1256           NaN             NaN                NaN        Seobandrio Putra
# 1257           NaN             NaN                NaN             Ban Foo Yap
# 1258           NaN             NaN                NaN             Shirley Ann
#
#      CONTACT TEL                     WORK EMAIL CONTACT EMAIL POSITION  \
# 0            NaN        maggie.chan@qdos.com.my           NaN      NaN
# 1            NaN             fadli@ramly.com.my           NaN      NaN
# 2            NaN     mohd.shafizzie@renesas.com           NaN      NaN
# 3            NaN  ahmad.khairuddin@swagelok.com           NaN      NaN
# 4            NaN            bazil@eppmfg.com.my           NaN      NaN
# ...          ...                            ...           ...      ...
# 1254         NaN                            NaN           NaN      NaN
# 1255         NaN                            NaN           NaN      NaN
# 1256         NaN                            NaN           NaN      NaN
# 1257         NaN                            NaN           NaN      NaN
# 1258         NaN                            NaN           NaN      NaN
#
#      SUBJECT OF INTEREST OTHER NOTES Search Status Link Reference  \
# 0                    NaN         NaN           NaN            NaN
# 1                    NaN         NaN           NaN            NaN
# 2                    NaN         NaN           NaN            NaN
# 3                    NaN         NaN           NaN            NaN
# 4                    NaN         NaN           NaN            NaN
# ...                  ...         ...           ...            ...
# 1254                 NaN         NaN           NaN            NaN
# 1255                 NaN         NaN           NaN            NaN
# 1256                 NaN         NaN           NaN            NaN
# 1257                 NaN         NaN           NaN            NaN
# 1258                 NaN         NaN           NaN            NaN
#
#      LinkedIn Profile
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1254              NaN
# 1255              NaN
# 1256              NaN
# 1257              NaN
# 1258              NaN
#
# [1259 rows x 18 columns]

# %% [markdown]
# Mapping SignalHire's data to template (applying Xlookup concept)

# %%
TemplateFilled_df

#Task 1 - mapping COMPANY NAME
# Create a copy of dftemplate_raw
dftemplate_t1 = TemplateFilled_df.copy()
# Create a dictionary mapping 'Raw Full Name' to 'phone' in filtered_df_t3, only for phone_type ''
company_mapping = dict(zip(SHdata_df['Full Name'], SHdata_df['Company']))
# Fill NaN values in 'CONTACT TEL' column of dftemplate_t3 using phone_mapping_t3
dftemplate_t1['COMPANY NAME'] = dftemplate_t1['COMPANY NAME'].fillna(dftemplate_t1['CONTACT NAME'].map(company_mapping))

#Task 2 - mapping POSITION
# Create a copy of dftemplate_raw
dftemplate_t2 = dftemplate_t1.copy()
# Create a dictionary mapping 'Raw Full Name' to 'phone' in filtered_df_t3, only for phone_type ''
position_mapping = dict(zip(SHdata_df['Full Name'], SHdata_df['Position']))
# Fill NaN values in 'CONTACT TEL' column of dftemplate_t3 using phone_mapping_t3
dftemplate_t2['POSITION'] = dftemplate_t2['POSITION'].fillna(dftemplate_t2['CONTACT NAME'].map(position_mapping))
dftemplate_t2[dftemplate_t2['CONTACT NAME']=='Angelyn Ser']

#Task 3 - mapping all Links to new column
dftemplate_t3 = dftemplate_t2.copy()
# List of link columns to be mapped
link_columns = ['Link1', 'Link2', 'Link3', 'Link4', 'Link5', 'Link6', 'Link7', 'Link8']

# Iterate through each link column
for link_col in link_columns:
    # Create a dictionary mapping for the current link column
    links_mapping = dict(zip(SHdata_df['Full Name'], SHdata_df[link_col]))
    
    # Ensure the current link column exists in dftemplate_t3
    if link_col not in dftemplate_t3.columns:
        dftemplate_t3[link_col] = None

    # Fill NaN values in the current link column with the mapped values from 'CONTACT NAME'
    dftemplate_t3[link_col] = dftemplate_t3[link_col].fillna(dftemplate_t3['CONTACT NAME'].map(links_mapping))


dftemplate_t3
# Out:
#        NO                              COMPANY NAME COMPANY ADDRESS  \
# 0     NaN                 QDOS Flexcircuits Sdn Bhd             NaN
# 1     NaN             ramly food processing sdn bhd             NaN
# 2     NaN          Renesas Semiconductor KL Sdn Bhd             NaN
# 3     NaN                                  ProEight             NaN
# 4     NaN  ECO PAPER PRODUCTS MANUFACTURING SDN BHD             NaN
# ...   ...                                       ...             ...
# 1254  NaN                   Recron(Malaysia)Sdn Bhd             NaN
# 1255  NaN                QL Marine Products Sdn Bhd             NaN
# 1256  NaN              Quantum Supplies (M) Sdn Bhd             NaN
# 1257  NaN            Spartan Peripheral (M) Sdn Bhd             NaN
# 1258  NaN                             Q-FIT SDN BHD             NaN
#
#      COMPANY ACTIVITIES COMPANY TEL COMPANY EMAIL COMPANY WEBSITE  \
# 0                   NaN         NaN           NaN             NaN
# 1                   NaN         NaN           NaN             NaN
# 2                   NaN         NaN           NaN             NaN
# 3                   NaN         NaN           NaN             NaN
# 4                   NaN         NaN           NaN             NaN
# ...                 ...         ...           ...             ...
# 1254                NaN         NaN           NaN             NaN
# 1255                NaN         NaN           NaN             NaN
# 1256                NaN         NaN           NaN             NaN
# 1257                NaN         NaN           NaN             NaN
# 1258                NaN         NaN           NaN             NaN
#
#      CONTACT SALUTATION            CONTACT NAME CONTACT TEL  ...  \
# 0                   NaN            Maggie  Chan         NaN  ...
# 1                   NaN              Mohd Fadli         NaN  ...
# 2                   NaN          Mohd Shafizzie         NaN  ...
# 3                   NaN        Ahmad Khairuddin         NaN  ...
# 4                   NaN     Bazil Suhaimi Buang         NaN  ...
# ...                 ...                     ...         ...  ...
# 1254                NaN  Mohd Fidha Uddin Alias         NaN  ...
# 1255                NaN                 Siti M.         NaN  ...
# 1256                NaN        Seobandrio Putra         NaN  ...
# 1257                NaN             Ban Foo Yap         NaN  ...
# 1258                NaN             Shirley Ann         NaN  ...
#
#      Link Reference LinkedIn Profile  \
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ...             ...              ...
# 1254            NaN              NaN
# 1255            NaN              NaN
# 1256            NaN              NaN
# 1257            NaN              NaN
# 1258            NaN              NaN
#
#                                                   Link1  \
# 0     https://www.linkedin.com/in/maggie-chan-9a0954222
# 1      https://www.linkedin.com/in/mohd-fadli-811a92129
# 2             https://www.linkedin.com/in/mohdshafizzie
# 3     https://www.linkedin.com/in/ahmad-khairuddin-8...
# 4     https://www.linkedin.com/in/bazil-suhaimi-buan...
# ...                                                 ...
# 1254  https://www.linkedin.com/in/mohd-fidha-uddin-a...
# 1255       https://www.linkedin.com/in/siti-m-81a000191
# 1256  https://www.linkedin.com/in/seobandrio-putra-6...
# 1257   https://www.linkedin.com/in/ban-foo-yap-6b7bba86
# 1258  https://www.linkedin.com/in/shirley-ann-307982269
#
#                                                 Link2 Link3 Link4 Link5 Link6  \
# 0                                                 NaN   NaN   NaN   NaN   NaN
# 1                                                 NaN   NaN   NaN   NaN   NaN
# 2                                                 NaN   NaN   NaN   NaN   NaN
# 3     https://www.facebook.com/ahmad.khairuddin.12382   NaN   NaN   NaN   NaN
# 4                                                 NaN   NaN   NaN   NaN   NaN
# ...                                               ...   ...   ...   ...   ...
# 1254                                              NaN   NaN   NaN   NaN   NaN
# 1255                                              NaN   NaN   NaN   NaN   NaN
# 1256                                              NaN   NaN   NaN   NaN   NaN
# 1257                                              NaN   NaN   NaN   NaN   NaN
# 1258                                              NaN   NaN   NaN   NaN   NaN
#
#      Link7 Link8
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 1254   NaN   NaN
# 1255   NaN   NaN
# 1256   NaN   NaN
# 1257   NaN   NaN
# 1258   NaN   NaN
#
# [1259 rows x 26 columns]

# %% [markdown]
# Save into Excel

# %%
# Define the output file path and name
output_file = os.path.join(folder_path, 'dftemplate_t3.xlsx')

# Save the DataFrame to an Excel file
dftemplate_t3.to_excel(output_file, index=False)

print(f"The DataFrame has been successfully saved to {output_file}")
# Out:
# The DataFrame has been successfully saved to C:/Users/uadrian/Downloads/MITS/SignalHire/SignalHire Export Record\dftemplate_t3.xlsx

# %% [markdown]
# Sorting out Links

# %%
# Part 1: Combine links into a single column
Links = SHdata_df[['Link1', 'Link2', 'Link3', 'Link4', 'Link5', 'Link6', 'Link7', 'Link8']]

# Melt the DataFrame to combine all link columns into one column
melted_links = Links.melt(value_name='Link').drop('variable', axis=1)

# Drop rows with NaN values
combined_links = melted_links.dropna()

# Reset the index
combined_links.reset_index(drop=True, inplace=True)

# Part 2: Extract and normalize domains
def extract_domain(url):
    parsed_url = urlparse(url)
    domain = parsed_url.netloc
    # Remove 'www.' prefix if present
    if domain.startswith('www.'):
        domain = domain[4:]
    return domain

# Apply the function to extract and normalize domains
combined_links['Domain'] = combined_links['Link'].apply(extract_domain)

# The resulting DataFrame with links and normalized domains
combined_links

#mapping Full Name to Links
Links_df = combined_links.copy()
# Create a dictionary mapping 'Raw Full Name' to 'phone' in filtered_df_t3, only for phone_type ''
link_mapping = dict(zip(SHdata_df['Full Name'], SHdata_df['Company']))
# Fill NaN values in 'CONTACT TEL' column of dftemplate_t3 using phone_mapping_t3
dftemplate_t1['COMPANY NAME'] = dftemplate_t1['COMPANY NAME'].fillna(dftemplate_t1['CONTACT NAME'].map(company_mapping))
# Out:
# C:\Users\uadrian\AppData\Local\Temp\ipykernel_22832\2163959525.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_links['Domain'] = combined_links['Link'].apply(extract_domain)
#                                                    Link        Domain
# 0     https://www.linkedin.com/in/bazil-suhaimi-buan...  linkedin.com
# 1      https://www.linkedin.com/in/adriad-choo-87b297a2  linkedin.com
# 2     https://www.linkedin.com/in/osman-pauzi-abdul-...  linkedin.com
# 3     https://www.linkedin.com/in/mithin-sukumaran-4...  linkedin.com
# 4     https://www.linkedin.com/in/sree-raguraman-6a7...  linkedin.com
# ...                                                 ...           ...
# 1337  http://www.tagged.com/photo_gallery.html?uid=3...    tagged.com
# 1338                        http://twitter.com/jlowwwww   twitter.com
# 1339                http://www.gravatar.com/leonardwein  gravatar.com
# 1340                       https://about.me/leonardwein      about.me
# 1341                     http://twitter.com/LeonardWein   twitter.com
#
# [1342 rows x 2 columns]
