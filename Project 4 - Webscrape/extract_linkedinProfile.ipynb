# %%
import pandas as pd
from googlesearch import search
from bs4 import BeautifulSoup
import requests
import time

# %%
def get_first_google_link(query):
    # Custom headers
    headers = {
        'User-agent':
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582'
    }
    
    # Perform Google search and get the search results
    try:
        # Construct the Google search URL
        url = 'https://www.google.com/search?q=' + query
        # Send GET request to the URL with custom headers
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for HTTP errors
    except Exception as e:
        print("An error occurred while performing the search:", str(e))
        return None
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find and extract the first search result link
    first_link = None
    search_results = soup.find_all('a')
    for link in search_results:
        href = link.get('href')
        if href.startswith('/url?q='):
            first_link = href.replace('/url?q=', '').split('&')[0]
            break
    
    # Find and extract the title of the first link
    title = soup.title.string if soup.title else None
    
    return {
        'query': query,
        'title': title,
        'link': first_link
    }

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_excel('salutation_seperated.xlsx')
df['Query'] = df['Full Name'] + ' Linkedin'
df1 = df.head(10)
df1
# Out:
#                                            Full Name  \
# 0  ASSOC PROF. Ir. Dr. SAIDDI ALI FIRDAUS B MOHAM...
# 1       ASSOC. PROF. IR. DR. MOHD DANIAL BIN IBRAHIM
# 2  BRIG. JEN. DATO' IR. HJ. NAJMUDDIN BIN HJ. JAA...
# 3                         DATO' Ir. AHMAD BIN HASSAN
# 4                     DATO' Ir. AHMAD MURAD BIN OMAR
# 5                           DATO' Ir. CHENG NYEK PAW
# 6                 DATO' Ir. Dr. ABU BAKAR BIN JAAFAR
# 7        DATO' Ir. Dr. MUKHLIS CHUA @ CHUA CHING KOK
# 8                         DATO' Ir. Dr. SEO KIAN HAW
# 9                          DATO' Ir. FOONG CHOY CHYE
#
#                  Salutation                                Name  \
# 0       ASSOC PROF. Ir. Dr.  SAIDDI ALI FIRDAUS B MOHAMED ISHAK
# 1      ASSOC. PROF. IR. DR.             MOHD DANIAL BIN IBRAHIM
# 2  BRIG. JEN. DATO' IR. HJ.  NAJMUDDIN BIN HJ. JAAFAR (BERSARA)
# 3                 DATO' Ir.                    AHMAD BIN HASSAN
# 4                 DATO' Ir.                AHMAD MURAD BIN OMAR
# 5                 DATO' Ir.                      CHENG NYEK PAW
# 6             DATO' Ir. Dr.                ABU BAKAR BIN JAAFAR
# 7             DATO' Ir. Dr.       MUKHLIS CHUA @ CHUA CHING KOK
# 8             DATO' Ir. Dr.                        SEO KIAN HAW
# 9                 DATO' Ir.                     FOONG CHOY CHYE
#
#                                                Query
# 0  ASSOC PROF. Ir. Dr. SAIDDI ALI FIRDAUS B MOHAM...
# 1  ASSOC. PROF. IR. DR. MOHD DANIAL BIN IBRAHIM L...
# 2  BRIG. JEN. DATO' IR. HJ. NAJMUDDIN BIN HJ. JAA...
# 3                DATO' Ir. AHMAD BIN HASSAN Linkedin
# 4            DATO' Ir. AHMAD MURAD BIN OMAR Linkedin
# 5                  DATO' Ir. CHENG NYEK PAW Linkedin
# 6        DATO' Ir. Dr. ABU BAKAR BIN JAAFAR Linkedin
# 7  DATO' Ir. Dr. MUKHLIS CHUA @ CHUA CHING KOK Li...
# 8                DATO' Ir. Dr. SEO KIAN HAW Linkedin
# 9                 DATO' Ir. FOONG CHOY CHYE Linkedin

# %%
# List to store results
results = []

# Iterate over queries in the DataFrame
for query in df1['Query']:
    result = get_first_google_link(query)
    if result:
        results.append(result)
    # Pause for a few seconds between requests
    time.sleep(5)

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display the results DataFrame
print(results_df)
# Out:
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DASSOC%2520PROF.%2520Ir.%2520Dr.%2520SAIDDI%2520ALI%2520FIRDAUS%2520B%2520MOHAMED%2520ISHAK%2520Linkedin&q=EgS3q2b9GJqMlLEGIjDc8PvDmtXGKis3YzF8ivDwEjOEaCb-SXFAPjqlN3nSaK7rxGxASNsUUoRi6AxX6OwyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DASSOC.%2520PROF.%2520IR.%2520DR.%2520MOHD%2520DANIAL%2520BIN%2520IBRAHIM%2520Linkedin&q=EgS3q2b9GKCMlLEGIjBbprw-SZAr3N_oh3PjSyxTB_iz0NJV9sOehOgmUo6GDalwn0otfxFQcvszBt_CWwoyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBRIG.%2520JEN.%2520DATO%27%2520IR.%2520HJ.%2520NAJMUDDIN%2520BIN%2520HJ.%2520JAAFAR%2520(BERSARA)%2520Linkedin&q=EgS3q2b9GKaMlLEGIjDC6DfT1i_u_x8LhWo0K4fmymowybgjQJrKO_iczjFsnanHQmhRzfOovG8Kx65TK5AyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520AHMAD%2520BIN%2520HASSAN%2520Linkedin&q=EgS3q2b9GKyMlLEGIjC5BNdTHFVEq56nmZFiB-P7ajbKEHWfAs6lC7Tuu9Xunpzs-SfzUC2FaQu1h0L-IjcyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520AHMAD%2520MURAD%2520BIN%2520OMAR%2520Linkedin&q=EgS3q2b9GLKMlLEGIjAAHXV0KM4jE6qElGEXOnnb1058GD5QWaa5NrvBIjMZtvGvDVJ0v5QHzJgF6QwhxtYyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520CHENG%2520NYEK%2520PAW%2520Linkedin&q=EgS3q2b9GLiMlLEGIjAg0hl7tlcSrcWu88w3dqC6qalucloEXlON0_9XXHdK0ALUkKnNQ81dyy5ivCNHaqkyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520Dr.%2520ABU%2520BAKAR%2520BIN%2520JAAFAR%2520Linkedin&q=EgS3q2b9GL6MlLEGIjDvOKizcUXzxGVplA6Q1d-LmWUOQGDZ68HZFly0ylzDd_qCqE6VtWwGrZHpUiCSsZcyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520Dr.%2520MUKHLIS%2520CHUA%2520%40%2520CHUA%2520CHING%2520KOK%2520Linkedin&q=EgS3q2b9GMSMlLEGIjCAYhaJfLJ0wjkeo45NrfSjNExi4xDuKgFT4TqO5ajLFdHMhyu3LMvjmbUFrgiJ-RIyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520Dr.%2520SEO%2520KIAN%2520HAW%2520Linkedin&q=EgS3q2b9GMqMlLEGIjDUM4Sg-yNAFlFTYLrb_G3rOT1xdEvILTaACU_sLGw96FStFs-bUh26UWBdaQ3kuisyAXJaAUM
# An error occurred while performing the search: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDATO%27%2520Ir.%2520FOONG%2520CHOY%2520CHYE%2520Linkedin&q=EgS3q2b9GM-MlLEGIjDblc49MTfk2bzZxjQhtSS2vZexU7fqUJKMGmcOiYLW0Nt843hkDHAcYuF_mlQqNj0yAXJaAUM
# Empty DataFrame
# Columns: []
# Index: []

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)\
            AppleWebKit/537.36 (KHTML, like Gecko) Cafari/537.36'}

query = 'test again'#df['Query'].head(1)
# search_results = #change to google.com/q=+
url = 'https://www.google.com?q=' + query
res = requests.get(url, headers=headers)
